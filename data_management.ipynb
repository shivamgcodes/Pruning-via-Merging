# %%
from classes import IMAGENET2012_CLASSES
import os
import csv

# %%
print(IMAGENET2012_CLASSES)
IMAGENET2012_CLASSES = list(IMAGENET2012_CLASSES.items())

print(IMAGENET2012_CLASSES[0])
# Out:
# OrderedDict([('n01440764', 'tench, Tinca tinca'), ('n01443537', 'goldfish, Carassius auratus'), ('n01484850', 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias'), ('n01491361', 'tiger shark, Galeocerdo cuvieri'), ('n01494475', 'hammerhead, hammerhead shark'), ('n01496331', 'electric ray, crampfish, numbfish, torpedo'), ('n01498041', 'stingray'), ('n01514668', 'cock'), ('n01514859', 'hen'), ('n01518878', 'ostrich, Struthio camelus'), ('n01530575', 'brambling, Fringilla montifringilla'), ('n01531178', 'goldfinch, Carduelis carduelis'), ('n01532829', 'house finch, linnet, Carpodacus mexicanus'), ('n01534433', 'junco, snowbird'), ('n01537544', 'indigo bunting, indigo finch, indigo bird, Passerina cyanea'), ('n01558993', 'robin, American robin, Turdus migratorius'), ('n01560419', 'bulbul'), ('n01580077', 'jay'), ('n01582220', 'magpie'), ('n01592084', 'chickadee'), ('n01601694', 'water ouzel, dipper'), ('n01608432', 'kite'), ('n01614925', 'bald eagle, Ame
# ...

# %%
val_dir = r'C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv'
os.path.join(val_dir,'something.csv')
for item, value in IMAGENET2012_CLASSES:
    file_name = os.path.join(val_dir, (item + '.csv'))
    
    with open(file_name, mode="w") as file:
        writer = csv.writer(file)
        writer.writerow([value,])
# Out:
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01440764.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01443537.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01484850.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01491361.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01494475.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01496331.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01498041.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01514668.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01514859.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01518878.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01530575.csv
# C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv\n01531178.csv
# ...

# %%
image_dir = 'C:/Users/hp/Desktop/mka on VIT-mae/Pruning-via-Merging/val_images'

# %%
for img_file_name in os.listdir(image_dir):
    
    csv_name = img_file_name[24:-5]
    
    csv_file_name = os.path.join(val_dir, (csv_name + '.csv'))
    
    with open(csv_file_name, mode = "a") as file:
        writer = csv.writer(file)
        writer.writerow([img_file_name,])
    
print('done')
# Out:
# done

# %%
import pandas as pd
import os
val_dir = r'C:\Users\hp\Desktop\mka on VIT-mae\Pruning-via-Merging\val_csv'
for val_csv_name in os.listdir(val_dir):
    print(val_csv_name)
    df = pd.read_csv(os.path.join(val_dir, val_csv_name), header=None)
    
    print(df.head())
    print(df.shape)
    print(df.iloc[0:2])
    print(str(df.iloc[1,0]))
    break
# Out:
# n01440764.csv
#                                         0
# 0                      tench, Tinca tinca
# 1  ILSVRC2012_val_00000293_n01440764.JPEG
# 2  ILSVRC2012_val_00002138_n01440764.JPEG
# 3  ILSVRC2012_val_00003014_n01440764.JPEG
# 4  ILSVRC2012_val_00006697_n01440764.JPEG
# (51, 1)
#                                         0
# 0                      tench, Tinca tinca
# 1  ILSVRC2012_val_00000293_n01440764.JPEG
# ILSVRC2012_val_00000293_n01440764.JPEG
